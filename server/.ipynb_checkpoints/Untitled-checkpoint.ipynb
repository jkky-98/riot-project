# %%
import requests
import json
import time
import pandas as pd
from tqdm import tqdm

API_KEY = "RGAPI-9b898ccb-b28d-4470-b518-3c26469adad7"

class RiotAPI:
    def __init__(self, API_KEY):
        self.API_KEY = API_KEY
        self.header = {"X-Riot-Token": API_KEY}

    def get_puuid_from_summonerName(self, summonerName):
        url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summonerName}"
        response = requests.get(url, headers=self.header)
        return response.json()['puuid']
    
    def get_matchid_lst_from_puuid(self, puuid):
        url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?"
        response = requests.get(url, headers=self.header)
        return response.json()
    
    def get_match_matchId(self, matchId):
        url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
        response = requests.get(url, headers=self.header)
        return response.json()             

    def get_match_Full(self, summonerName):
        puuid = self.get_puuid_from_summonerName(summonerName)
        matchid_lst = self.get_matchid_lst_from_puuid(puuid)
        match_lst = []
        for matchId in tqdm(matchid_lst):
            match_lst.append(self.get_match_matchId(matchId))
            time.sleep(1.2)
        return match_lst
    
    def get_match_timeline(self, matchId):
        url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}/timeline"
        response = requests.get(url, headers=self.header)
        return response.json()
        
    
test = RiotAPI(API_KEY)

# %%
obj1 = test.get_match_Full("zi존준기123#KR1")[1]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:31<00:00,  1.60s/it]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 json(obj1)
#
# TypeError: 'module' object is not callable

# %%
print(json.dumps(obj1, indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "KR_6962199686",
#         "participants": [
#             "f3t2KepDYEPq8lCeoeWs1lJsvCy2I3W_e8VTrcBuQFdDc9LdAZn_Fo_AEVDyiUBnhPIzom_SxmF6iw",
#             "TTwx8gjCjBUNf2D_uUJM7-NUMYFrus-BJ6aK5wICcrMP4VZH5RsHkGxyeHOyc--FxxWbv5bNPq9GsQ",
#             "lnsUH2vw42x6XNlJ5KAE05sbOlzBm5YDSvS-fGqjRa5S4EBAfeXjSU8acdrLjWIH-9e3blc8J4FfOw",
#             "GWjfFkQbcxN_igZ4HUVE0rXvqCLQfcQV4LYZnHzwcs4nyVu25tkZDNF_Eli61PMETKbnS9-Ek2pTfA",
#             "qhVPatfyiYWBD03B_xgQ2VLNngXZdMiQXVuFkEmMf6Fde2vEFa2pmtEt9-GgVxYxuyGvhrRN7A1_rA",
#             "i0j85JrULcQznDMQnS5SBnycLdL1ukQb_1Cw9fcmDSJnwiqUgpT4Rd9oWFIW-VeJT9yh1Q8CPQ8qpA",
#             "4cM9bFBxEfFlh__qcw4a_Ynt1C73lfFA0Q3IvT7yHLDAwM1cAeC7rP1Zyysq_pbdbMhQSQZhkGwxjw",
#             "dDoajmm13CBibyMlKTUmKO9y1j9YIKRQlpiWbguSC_EQ6DY75TBhZikI4GyGH39cVkpLX8_99xyZXA",
#             "9UBKc41yCgPuhVCY797W4HooLyJmrq1K4spkaseHvqpiwmJMICHZcbxarw5qUjUKgEvthEmuXeWSVw",
# ...

# %%
import pandas as pd

class ParticipantDataFrame:
    def __init__(self, json_data):
        self.json_data = json_data
        self.participants_data = json_data['info']['participants']

    def get_n(self, data):
        # 데이터프레임을 만들기 위한 빈 리스트들을 생성합니다.
        num_data = len(data_lst)
        champion_names = []
        column_ = []
        
        # 각 참가자 정보를 반복하면서 데이터를 추출합니다.
        for participant in self.participants_data:
            champion_names.append(participant['championName'])
            column_.append(participant[data])

        # 데이터프레임을 생성합니다.
        data = {
            'ChampionName': champion_names,
            data : column_
        }

        df = pd.DataFrame(data)
        return df
    
    def get_clg(self, data)
    # 데이터프레임을 만들기 위한 빈 리스트들을 생성합니다.
        num_data = len(data_lst)
        champion_names = []
        column_ = []
        
        # 각 참가자 정보를 반복하면서 데이터를 추출합니다.
        for participant in self.participants_data:
            champion_names.append(participant['championName'])
            column_.append(participant[data])

        # 데이터프레임을 생성합니다.
        data = {
            'ChampionName': champion_names,
            data : column_
        }

        df = pd.DataFrame(data)
        return df
# 주어진 JSON 데이터 예시
json_data = {
    "info": {
        "participants": [
            {
                "championName": "Aatrox",
                "assists": 10,
                "deaths": 5,
                "kills": 8
            },
            {
                "championName": "Ahri",
                "assists": 7,
                "deaths": 3,
                "kills": 12
            },
            # 나머지 참가자 정보들...
        ]
    }
}

# ParticipantDataFrame 클래스를 사용하여 데이터프레임 생성
participant_df = ParticipantDataFrame(json_data)
df = participant_df.create_dataframe()

# 데이터프레임 출력
print(df)

# %%
tl1 = test.get_match_timeline("KR_6961713821")
tl1
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6961713821',
#   'participants': ['onzpaKK-V4BWINOlxzE6UmOjE13H1SlUXJabHDI4E1SYmNH_DkC65uWUzedqjqPyrF7KSK-kXN9i8g',
#    'Yg7JFBWjbhmxKqM3gtdxIlxpa-5Z-o9As1i7mCDYAX5B3ayCndav2rLSlrpBOBzyumrJFTnOMyXNhA',
#    'hRLkEg7OlKdKaR6FyA62ya2Cj7Q-20wItjABBkA8jH9wAmRtinv7UbtQbJRITogvQhu2GvEaMZ2gvw',
#    '9UBKc41yCgPuhVCY797W4HooLyJmrq1K4spkaseHvqpiwmJMICHZcbxarw5qUjUKgEvthEmuXeWSVw',
#    'VhICuvch_7KkpqiJ5B6xUHQJYlv0-TjCFTfFZ2aRlSuI-J3q1yCE2n9VrptVzFEdXDMP71qW3hbNAA',
#    'S8EZ7N3NkdOnB5JqO7LRfKhwV-jgDA4pOgzOHXdCkTg6PQ1sDF64fxKVKdoIoh3IPeKemOgq5idx1Q',
#    'hB1sDFTyQI_kXwVQCT79VngWUmWgDu2YT0e2-tlaHELSmw9SaZn7DpjhNTj5m7pxV21MwZfC_9_IOQ',
#    'hfL4jDNbQaryTJwa0oqBBMPaEA6clcAdvln3JCzthHIN8-OMlGnlYu-HMl-mstYkIJmVR8rgQ2Yrdw',
#    'e_V4tOx-UpagXxad5DXXLj5CwQoLMKlRDGiuqtjAVJnpSvf5qiR_K2tD5yKSfKY7FgSjsvhscay-hg',
#    '4eRDOMV1NROyecDm1hjGKN5GoW7JGW6ASvvV17YPvmSR9qOMUjsVSDwDOwdF5SktDvhX3r2eL01Vsg']},
# ...
