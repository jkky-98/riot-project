# %%
import requests
import json
import time
import pandas as pd
from tqdm import tqdm

API_KEY = "RGAPI-41ddc906-11ba-43fb-8f5d-9cc894ce7f0b"

class RiotAPI:
    def __init__(self, API_KEY):
        self.API_KEY = API_KEY
        self.header = {"X-Riot-Token": API_KEY}

    def get_puuid_from_summonerName(self, summonerName):
        url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summonerName}"
        response = requests.get(url, headers=self.header)
        return response.json()['puuid']
    
    def get_matchid_lst_from_puuid(self, puuid):
        url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?"
        response = requests.get(url, headers=self.header)
        return response.json()
    
    def get_match_matchId(self, matchId):
        url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
        response = requests.get(url, headers=self.header)
        return response.json()             

    def get_match_Full(self, summonerName):
        puuid = self.get_puuid_from_summonerName(summonerName)
        matchid_lst = self.get_matchid_lst_from_puuid(puuid)
        match_lst = []
        for matchId in tqdm(matchid_lst):
            match_lst.append(self.get_match_matchId(matchId))
            time.sleep(1.2)
        return match_lst
    
test = RiotAPI(API_KEY)
print(test.get_match_Full("zi존준기123#KR1")[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:31<00:00,  1.57s/it]
# {'metadata': {'dataVersion': '2', 'matchId': 'KR_6960476767', 'participants': ['zdmV0dF5uaGCn4ZR-V-7JA1c68afE-Ghew9Zao_JQMbKdrbXKjcKPzuXpptUmze5EgjhS-nTE78rTQ', 'uTitLJUl7BsTgleG13B722--cU32g6bYa2eZzcbkg4z1Ou-Cd7-8M078N2GuFQOJStNjk_uREg7QPA', 'h7rr8N6XeEpGL9KwtstqdWso9JXvlYrwo1cAnukt5B1qbUxPsmtmtY3gxcGjnvAbYmvw6kutrh6pMQ', 'aH0DedcBSuP9MTKu08XF73MFxYLeeys1Q3HyrZIyIJGyt4x1NN09y793bH7POHmgA4A686AAnB39Bw', 'wrz1jpCLAjhlReUxypZRFCoesCRhA1qNX745K6ULZsXJ4mlrLrAACFeNqSatyoBlC0L22Y3X_UZUMQ', 'bnpSC-onyTnU0Eo4AIcty51g3-JvP43E05hAXVpqhpqkr3iYi9nmGiFRb_mNV47c38Zt680tDQ-zmQ', '5z1o0l_TwrGteYD0l8KpYW1dHUDGqtUcuikez4JKyl-ZEhU75RVSXLOm8qae4ZmV5HNJp5RKxXWQIA', '9UBKc41yCgPuhVCY797W4HooLyJmrq1K4spkaseHvqpiwmJMICHZcbxarw5qUjUKgEvthEmuXeWSVw', 'mqsvKgl28D6Pa6r3g3h0b3qHeDrClZojIADxHfP_q3i9q-QdZf7Eeurc1y3B8Q1vdwziUvwx-Kcxvg', 'sTJCvnM4_HXrqZBklb8CmYYYMSec7e39cg8mU5H7t-tOyBV9aQGQuZG8_Fwhy72X2-RzhBKK1dV9Tw']}, 'info': {'endOfGameResult': 'GameComplete', 'gameCreation': 1708628687195, 'gameDuration': 1338, 'gameEndTimestamp': 1708630037995, 'gameId': 6960476767, 'gameMode': 'ARAM', 'gameName': 'teambuilder-match-6960476767', 'gameStartTimestamp': 1708628699335, 'gameType': 'MATCHED_GAME', 'gameVersion': '14.4.561.3953', 'mapId': 12, 'participants': [{'allInPings': 0, 'assistMePings': 0, 'assists': 44, 'baronKills': 0, 'basicPings': 0, 'bountyLevel': 0, 'challenges': {'12AssistStreakCount': 1, 'abilityUses': 109, 'acesBefore15Minutes': 1, 'alliedJungleMonsterKills': 0, 'baronTakedowns': 0, 'blastConeOppositeOpponentCount': 0, 'bountyGold': 825, 'buffsStolen': 0, 'completeSupportQuestInTime': 0, 'controlWardsPlaced': 0, 'damagePerMinute': 1686.5519008061244, 'damageTakenOnTeamPercentage': 0.14998032451692145, 'dancedWithRiftHerald': 0, 'deathsByEnemyChamps': 12, 'dodgeSkillShotsSmallWindow': 0, 'doubleAces': 0, 'dragonTakedowns': 0, 'effectiveHealAndShielding': 5896.3759765625, 'elderDragonKillsWithOpposingSoul': 0, 'elderDragonMultikills': 0, 'enemyChampionImmobilizations': 10, 'enemyJungleMonsterKills': 0, 'epicMonsterKillsNearEnemyJungler': 0, 'epicMonsterKillsWithin30SecondsOfSpawn': 0, 'epicMonsterSteals': 0, 'epicMonsterStolenWithoutSmite': 0, 'firstTurretKilled': 0, 'flawlessAces': 0, 'fullTeamTakedown': 14, 'gameLength': 1338.7332603999998, 'getTakedownsInAllLanesEarlyJungleAsLaner': 0, 'goldPerMinute': 784.4727816605609, 'hadOpenNexus': 0, 'immobilizeAndKillWithAlly': 4, 'initialBuffCount': 0, 'initialCrabCount': 0, 'jungleCsBefore10Minutes': 0, 'junglerTakedownsNearDamagedEpicMonster': 0, 'kTurretsDestroyedBeforePlatesFall': 0, 'kda': 4.583333333333333, 'killAfterHiddenWithAlly': 5, 'killParticipation': 0.7857142857142857, 'killedChampTookFullTeamDamageSurvived': 0, 'killingSprees': 1, 'killsNearEnemyTurret': 0, 'killsOnOtherLanesEarlyJungleAsLaner': 0, 'killsOnRecentlyHealedByAramPack': 0, 'killsUnderOwnTurret': 5, 'killsWithHelpFromEpicMonster': 0, 'knockEnemyIntoTeamAndKill': 0, 'landSkillShotsEarlyGame': 5, 'laneMinionsFirst10Minutes': 15, 'legendaryCount': 0, 'legendaryItemUsed': [6676, 3004, 3094, 3036, 3036, 3031], 'lostAnInhibitor': 1, 'maxKillDeficit': 2, 'mejaisFullStackInTime': 0, 'moreEnemyJungleThanOpponent': 0, 'multiKillOneSpell': 0, 'multiTurretRiftHeraldCount': 0, 'multikills': 1, 'multikillsAfterAggressiveFlash': 0, 'outerTurretExecutesBefore10Minutes': 0, 'outnumberedKills': 4, 'outnumberedNexusKill': 0, 'perfectDragonSoulsTaken': 0, 'perfectGame': 0, 'pickKillWithAlly': 44, 'poroExplosions': 0, 'quickCleanse': 0, 'quickFirstTurret': 0, 'quickSoloKills': 0, 'riftHeraldTakedowns': 0, 'saveAllyFromDeath': 0, 'scuttleCrabKills': 0, 'skillshotsDodged': 8, 'skillshotsHit': 19, 'snowballsHit': 0, 'soloBaronKills': 0, 'soloKills': 1, 'stealthWardsPlaced': 0, 'survivedSingleDigitHpCount': 0, 'survivedThreeImmobilizesInFight': 0, 'takedownOnFirstTurret': 0, 'takedowns': 55, 'takedownsAfterGainingLevelAdvantage': 0, 'takedownsBeforeJungleMinionSpawn': 5, 'takedownsFirstXMinutes': 35, 'takedownsInAlcove': 0, 'takedownsInEnemyFountain' ...

# %%
obj1 = test.get_match_Full("zi존준기123#KR1")[5]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:31<00:00,  1.55s/it]

# %%
print(obj1)
# Out:
# {'metadata': {'dataVersion': '2', 'matchId': 'KR_6960378423', 'participants': ['leYyRKIQo1_dRaec7dT-exGFmwoRkJEY8tHTA1OGGJXtEJ8Ex89XqUY1G_lU84RRzDf_WPyEdM9a_Q', '4rz2dHCRdTPEvw_2HHX5gR_VJSPOd31zZqwdf8mMhKz5CftISmtogziD3wn-gyvVt6CXKGb9zFLt6w', 'mqsvKgl28D6Pa6r3g3h0b3qHeDrClZojIADxHfP_q3i9q-QdZf7Eeurc1y3B8Q1vdwziUvwx-Kcxvg', '9UBKc41yCgPuhVCY797W4HooLyJmrq1K4spkaseHvqpiwmJMICHZcbxarw5qUjUKgEvthEmuXeWSVw', 'NAtwwajEHyW7P2Z0vIAh0YQVS7OAzJX_DsewkYZEitRmwwYw6N6glLuXucqpQI-uDV7Dxe2nWivTHw', '0mWzuGhSB6g33icJyzpN2TIRWT8xjtxBGXm5AL3CfAdHR6Jd0yiVZol3NODBE2ntdgTvXx1fUWo3LA', 'vvIM_N0hBHNw0flWVhAHW-7_U8c4lg4AUTJUaAhpjA-8iNkUKmfhVtB5YUft7bS-OzhQmsJgaMV0aw', 'KiHDOHfId7C2Dq_rLS-baeHTvmn6RgjJNIw2TdcdwdkIv6QIxjvCoR1dkG0uin1Wc09bbBLNRL3EWA', 'lWEEnAxU2WqY5a9oXrKLeG4IvHgCqw-Od_ywdtfx526NN2mpIjoOcsP9lhpOxgsFrJCK5ClKiKG41Q', 'I-DSeKZiA-DAkibinwIccKlDAQfFldJNB1wjO53-vMwW9-51qHFsBDplBiI119fZ7rdTOLIXcNhxAg']}, 'info': {'endOfGameResult': 'GameComplete', 'gameCreation': 1708620434966, 'gameDuration': 1630, 'gameEndTimestamp': 1708622094238, 'gameId': 6960378423, 'gameMode': 'CLASSIC', 'gameName': 'teambuilder-match-6960378423', 'gameStartTimestamp': 1708620464275, 'gameType': 'MATCHED_GAME', 'gameVersion': '14.4.561.3953', 'mapId': 11, 'participants': [{'allInPings': 0, 'assistMePings': 4, 'assists': 8, 'baronKills': 0, 'basicPings': 0, 'bountyLevel': 0, 'challenges': {'12AssistStreakCount': 0, 'abilityUses': 279, 'acesBefore15Minutes': 0, 'alliedJungleMonsterKills': 0, 'baronTakedowns': 0, 'blastConeOppositeOpponentCount': 0, 'bountyGold': 0, 'buffsStolen': 0, 'completeSupportQuestInTime': 0, 'controlWardsPlaced': 1, 'damagePerMinute': 987.7118298436153, 'damageTakenOnTeamPercentage': 0.3281025916988716, 'dancedWithRiftHerald': 0, 'deathsByEnemyChamps': 4, 'dodgeSkillShotsSmallWindow': 25, 'doubleAces': 0, 'dragonTakedowns': 0, 'earlyLaningPhaseGoldExpAdvantage': 0, 'effectiveHealAndShielding': 0, 'elderDragonKillsWithOpposingSoul': 0, 'elderDragonMultikills': 0, 'enemyChampionImmobilizations': 200, 'enemyJungleMonsterKills': 0, 'epicMonsterKillsNearEnemyJungler': 0, 'epicMonsterKillsWithin30SecondsOfSpawn': 0, 'epicMonsterSteals': 0, 'epicMonsterStolenWithoutSmite': 0, 'firstTurretKilled': 0, 'flawlessAces': 0, 'fullTeamTakedown': 3, 'gameLength': 1630.1436703, 'getTakedownsInAllLanesEarlyJungleAsLaner': 0, 'goldPerMinute': 396.4107318182432, 'hadOpenNexus': 0, 'highestChampionDamage': 1, 'highestCrowdControlScore': 1, 'immobilizeAndKillWithAlly': 7, 'initialBuffCount': 0, 'initialCrabCount': 0, 'jungleCsBefore10Minutes': 0, 'junglerTakedownsNearDamagedEpicMonster': 0, 'kTurretsDestroyedBeforePlatesFall': 0, 'kda': 3.5, 'killAfterHiddenWithAlly': 0, 'killParticipation': 0.6666666666666666, 'killedChampTookFullTeamDamageSurvived': 0, 'killingSprees': 2, 'killsNearEnemyTurret': 1, 'killsOnOtherLanesEarlyJungleAsLaner': 1, 'killsOnRecentlyHealedByAramPack': 0, 'killsUnderOwnTurret': 1, 'killsWithHelpFromEpicMonster': 1, 'knockEnemyIntoTeamAndKill': 7, 'landSkillShotsEarlyGame': 11, 'laneMinionsFirst10Minutes': 65, 'laningPhaseGoldExpAdvantage': 0, 'legendaryCount': 0, 'legendaryItemUsed': [6662, 3068, 8020], 'lostAnInhibitor': 0, 'maxCsAdvantageOnLaneOpponent': 13, 'maxKillDeficit': 0, 'maxLevelLeadLaneOpponent': 2, 'mejaisFullStackInTime': 0, 'moreEnemyJungleThanOpponent': 0, 'multiKillOneSpell': 0, 'multiTurretRiftHeraldCount': 0, 'multikills': 0, 'multikillsAfterAggressiveFlash': 0, 'outerTurretExecutesBefore10Minutes': 0, 'outnumberedKills': 0, 'outnumberedNexusKill': 0, 'perfectDragonSoulsTaken': 0, 'perfectGame': 0, 'pickKillWithAlly': 8, 'playedChampSelectPosition': 1, 'poroExplosions': 0, 'quickCleanse': 0, 'quickFirstTurret': 0, 'quickSoloKills': 0, 'riftHeraldTakedowns': 0, 'saveAllyFromDeath': 0, 'scuttleCrabKills': 0, 'skillshotsDodged': 154, 'skillshotsHit': 34, 'snowballsHit': 0, 'soloBaronKills': 0, 'soloKills': 3, 'stealthWardsPlaced': 4, 'survivedSingleDigitHpCount': 0, 'survivedThreeImmobilizesInFight': 28, 'takedownOnFirstTurret': 0 ...
